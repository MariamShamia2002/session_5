# %%
import pandas as pd
df = pd.read_csv('data/raw/chess_games.csv')

# %%
df.head()
# Out:
#    game_id  rated  turns victory_status winner time_increment       white_id  \
# 0        1  False     13    Out of Time  White           15+2       bourgris
# 1        2   True     16         Resign  Black           5+10           a-00
# 2        3   True     61           Mate  White           5+10         ischia
# 3        4   True     61           Mate  White           20+0  daniamurashov
# 4        5   True     95           Mate  White           30+3      nik221107
#
#    white_rating      black_id  black_rating  \
# 0          1500          a-00          1191
# 1          1322     skinnerua          1261
# 2          1496          a-00          1500
# 3          1439  adivanov2009          1454
# 4          1523  adivanov2009          1469
#
#                                                moves opening_code  \
# 0  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...          D10
# 1  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...          B00
# ...

# %%
df.shape
# Out:
# (20058, 17)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns.tolist()
# Out:
# ['game_id',
#  'rated',
#  'turns',
#  'victory_status',
#  'winner',
#  'time_increment',
#  'white_id',
#  'white_rating',
#  'black_id',
#  'black_rating',
#  'moves',
#  'opening_code',
#  'opening_moves',
#  'opening_fullname',
#  'opening_shortname',
#  'opening_response',
#  'opening_variation']

# %%
df['moves'].duplicated().sum()
# Out:
# np.int64(1138)

# %%
df['opening_response'].isna().mean() * 100
# Out:
# np.float64(93.982450892412)

# %%
df['opening_variation'].isna().mean() * 100
# Out:
# np.float64(28.218167314787117)

# %%
df['turns'].min()
# Out:
# np.int64(1)

# %%
df[df['turns'] == df['turns'].min()]
# Out:
#        game_id  rated  turns victory_status winner time_increment  \
# 1946      1947   True      1         Resign  Black           10+0
# 1977      1978  False      1    Out of Time  White          10+60
# 4115      4116  False      1    Out of Time  White           5+15
# 4473      4474  False      1    Out of Time  White            5+5
# 4828      4829   True      1         Resign  White           10+0
# 5496      5497  False      1    Out of Time  White           5+15
# 5875      5876   True      1         Resign  White           10+0
# 6040      6041  False      1    Out of Time  White          60+60
# 9229      9230   True      1         Resign  White           10+0
# 11742    11743  False      1         Resign  White          10+25
# 11963    11964  False      1    Out of Time  White          15+30
# 12679    12680  False      1    Out of Time  White           5+60
# 13557    13558  False      1    Out of Time  White          20+10
# ...
